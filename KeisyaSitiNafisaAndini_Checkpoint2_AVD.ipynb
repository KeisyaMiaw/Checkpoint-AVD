# %% [markdown]
# # Library

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/smartphones_cleaned_v6_new.csv")

df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# ## Sumber Data
#
# Dataset yang digunakan dalam analisis ini berasal dari [Kaggle: Smartphone Dataset] (https://www.kaggle.com/datasets/informrohit1/smartphones-dataset)

# %% [markdown]
# # Struktur dan Tipe Data

# %%
print("Menampilkan Beberapa Row Data:")
df.head(10)
# Out:
# Menampilkan Beberapa Row Data:
#   brand_name                                    model  price  rating  has_5g  \
# 0    oneplus                            OnePlus 11 5G  54999    89.0    True
# 1    oneplus                OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2    samsung                    Samsung Galaxy A14 5G  16499    75.0    True
# 3   motorola                     Motorola Moto G62 5G  14999    81.0    True
# 4     realme                       Realme 10 Pro Plus  24999    82.0    True
# 5    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0    True
# 6      apple                          Apple iPhone 14  65999    81.0    True
# 7     xiaomi            Xiaomi Redmi Note 12 Pro Plus  29999    86.0    True
# 8    nothing                          Nothing Phone 1  26749    85.0    True
# 9    oneplus                       OnePlus Nord 2T 5G  28999    84.0    True
#
#    has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
print("Menampilkan tipe data pada setiap kolom:")
df.dtypes
# Out:
# Menampilkan tipe data pada setiap kolom:
# brand_name                    object
# model                         object
# price                          int64
# rating                       float64
# has_5g                          bool
# has_nfc                         bool
# has_ir_blaster                  bool
# processor_brand               object
# num_cores                    float64
# processor_speed              float64
# battery_capacity             float64
# fast_charging_available        int64
# fast_charging                float64
# ram_capacity                 float64
# internal_memory              float64
# screen_size                  float64
# refresh_rate                   int64
# num_rear_cameras               int64
# num_front_cameras            float64
# os                            object
# primary_camera_rear          float64
# primary_camera_front         float64
# extended_memory_available      int64
# extended_upto                float64
# ...

# %% [markdown]
# # Jumlah Kolom dan Baris

# %%
print("menampikan jumlah kolom dan baris")

df.shape
# Out:
# menampikan jumlah kolom dan baris
# (980, 26)

# %% [markdown]
# # Statistik Deskriptif

# %%
print("\nMenampilkan statistik deskriptif:")
df.describe()
# Out:
# Menampilkan statistik deskriptif:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  879.000000  974.000000       938.000000
# mean    32520.504082   78.258248    7.772074         2.427217
# std     39531.812669    7.402854    0.836845         0.464090
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   74.000000    8.000000         2.050000
# 50%     19994.500000   80.000000    8.000000         2.300000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# std         1009.540054                 0.353205      34.277870      2.744378
# ...

# %%
print("\nMenghitung rata-rata:")
df.mean(numeric_only=True)
# Out:
# Menghitung rata-rata:
# price                        32520.504082
# rating                          78.258248
# has_5g                           0.560204
# has_nfc                          0.401020
# has_ir_blaster                   0.162245
# num_cores                        7.772074
# processor_speed                  2.427217
# battery_capacity              4817.748194
# fast_charging_available          0.854082
# fast_charging                   46.126138
# ram_capacity                     6.560204
# internal_memory                141.036735
# screen_size                      6.536765
# refresh_rate                    92.256122
# num_rear_cameras                 2.814286
# num_front_cameras                1.029713
# primary_camera_rear             50.319286
# primary_camera_front            16.589128
# extended_memory_available        0.630612
# extended_upto                  736.064000
# resolution_width              1075.852041
# resolution_height             2214.663265
# ...

# %%
print("\nMenghitung median:")
df.median(numeric_only=True)
# Out:
# Menghitung median:
# price                        19994.50
# rating                          80.00
# has_5g                           1.00
# has_nfc                          0.00
# has_ir_blaster                   0.00
# num_cores                        8.00
# processor_speed                  2.30
# battery_capacity              5000.00
# fast_charging_available          1.00
# fast_charging                   33.00
# ram_capacity                     6.00
# internal_memory                128.00
# screen_size                      6.58
# refresh_rate                    90.00
# num_rear_cameras                 3.00
# num_front_cameras                1.00
# primary_camera_rear             50.00
# primary_camera_front            16.00
# extended_memory_available        1.00
# extended_upto                 1024.00
# resolution_width              1080.00
# resolution_height             2400.00
# dtype: float64

# %%
print("\nMenghitung standar deviasi:")
df.std(numeric_only=True)
# Out:
# Menghitung standar deviasi:
# price                        39531.812669
# rating                           7.402854
# has_5g                           0.496616
# has_nfc                          0.490355
# has_ir_blaster                   0.368864
# num_cores                        0.836845
# processor_speed                  0.464090
# battery_capacity              1009.540054
# fast_charging_available          0.353205
# fast_charging                   34.277870
# ram_capacity                     2.744378
# internal_memory                107.134516
# screen_size                      0.349162
# refresh_rate                    28.988052
# num_rear_cameras                 0.776441
# num_front_cameras                0.169882
# primary_camera_rear             33.000968
# primary_camera_front            10.876802
# extended_memory_available        0.482885
# extended_upto                  366.894911
# resolution_width               290.164931
# resolution_height              516.484254
# ...

# %%
print("\nMenghitung korelasi antar kolom numerik:")
df.corr(numeric_only=True)
# Out:
# Menghitung korelasi antar kolom numerik:
#                               price    rating    has_5g   has_nfc  \
# price                      1.000000  0.283504  0.305066  0.470951
# rating                     0.283504  1.000000  0.596087  0.474754
# has_5g                     0.305066  0.596087  1.000000  0.481702
# has_nfc                    0.470951  0.474754  0.481702  1.000000
# has_ir_blaster            -0.015807  0.156421  0.105542 -0.032541
# num_cores                 -0.048561  0.199741  0.139607  0.026165
# processor_speed            0.474049  0.628446  0.609583  0.609664
# battery_capacity          -0.159232 -0.015581 -0.013237 -0.106104
# fast_charging_available    0.116739  0.542814  0.355858  0.237947
# fast_charging              0.277591  0.527613  0.440624  0.383231
# ram_capacity               0.386002  0.757613  0.533957  0.458336
# internal_memory            0.557168  0.481070  0.403837  0.413071
# screen_size                0.113253  0.298272  0.230598  0.103099
# ...

# %% [markdown]
# # DATA PREPARATION

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/smartphones_cleaned_v6_new.csv")
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# # Sumber Data
# Dataset yang digunakan dalam analisis ini berasal dari [Kaggle: Smartphone Dataset] (https://www.kaggle.com/datasets/informrohit1/smartphones-dataset)

# %% [markdown]
# # Missing Values

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase.

# %%
print("Menampilkan missing values:")
(df.isna().sum() / len(df)) * 100
# Out:
# Menampilkan missing values:
# brand_name                    0.000000
# model                         0.000000
# price                         0.000000
# rating                       10.306122
# has_5g                        0.000000
# has_nfc                       0.000000
# has_ir_blaster                0.000000
# processor_brand               2.040816
# num_cores                     0.612245
# processor_speed               4.285714
# battery_capacity              1.122449
# fast_charging_available       0.000000
# fast_charging                21.530612
# ram_capacity                  0.000000
# internal_memory               0.000000
# screen_size                   0.000000
# refresh_rate                  0.000000
# num_rear_cameras              0.000000
# num_front_cameras             0.408163
# os                            1.428571
# primary_camera_rear           0.000000
# primary_camera_front          0.510204
# extended_memory_available     0.000000
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom extended upto

# %%
df[df['extended_upto'].isnull()]
# Out:
#     brand_name                            model     price     rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.00  89.000000    True
# 4       realme               Realme 10 Pro Plus  24999.00  82.000000    True
# 6        apple                  Apple iPhone 14  65999.00  81.000000    True
# 7       xiaomi    Xiaomi Redmi Note 12 Pro Plus  29999.00  86.000000    True
# 8      nothing                  Nothing Phone 1  26749.00  85.000000    True
# ..         ...                              ...       ...        ...     ...
# 972       itel                        itel A23s   4787.00  78.258248   False
# 973     google               Google Pixel 8 Pro  69230.25  80.000000    True
# 974       vivo                    Vivo X Fold 2  69230.25  78.258248    True
# 975   motorola       Motorola Moto Edge S30 Pro  34990.00  83.000000    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.00  85.000000    True
#
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom extended memory available

# %%
df[df['extended_memory_available'].isnull()]
# Out:
#     brand_name                            model     price     rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.00  89.000000    True
# 4       realme               Realme 10 Pro Plus  24999.00  82.000000    True
# 6        apple                  Apple iPhone 14  65999.00  81.000000    True
# 7       xiaomi    Xiaomi Redmi Note 12 Pro Plus  29999.00  86.000000    True
# 8      nothing                  Nothing Phone 1  26749.00  85.000000    True
# ..         ...                              ...       ...        ...     ...
# 972       itel                        itel A23s   4787.00  78.258248   False
# 973     google               Google Pixel 8 Pro  69230.25  80.000000    True
# 974       vivo                    Vivo X Fold 2  69230.25  78.258248    True
# 975   motorola       Motorola Moto Edge S30 Pro  34990.00  83.000000    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.00  85.000000    True
#
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom fast charging

# %%
df[df['fast_charging'].isnull()]
# Out:
#     brand_name                     model   price  rating  has_5g  has_nfc  \
# 3     motorola      Motorola Moto G62 5G   14999    81.0    True    False
# 6        apple           Apple iPhone 14   65999    81.0    True     True
# 15       apple           Apple iPhone 13   62999    79.0    True     True
# 25     samsung  Samsung Galaxy S20 FE 5G   31239    88.0    True     True
# 27       apple   Apple iPhone 14 Pro Max  129990    76.0    True     True
# ..         ...                       ...     ...     ...     ...      ...
# 965      ikall                 iKall Z18    6799    61.0   False    False
# 966    oukitel               Oukitel WP9   25899    72.0   False     True
# 972       itel                 itel A23s    4787     NaN   False    False
# 978   motorola      Motorola Moto G91 5G   19990    80.0    True     True
# 979    samsung    Samsung Galaxy M52s 5G   24990    74.0    True    False
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom rating

# %%
df[df['rating'].isnull()]
# Out:
#     brand_name                        model   price  rating  has_5g  has_nfc  \
# 14     samsung  Samsung Galaxy S23 Ultra 5G  114990     NaN    True     True
# 29     oneplus               OnePlus 11 Pro   69999     NaN    True     True
# 37     samsung  Samsung Galaxy S22 Ultra 5G   91999     NaN    True     True
# 49     samsung        Samsung Galaxy A74 5G   42999     NaN    True     True
# 69        oppo             Oppo Find N Fold   99990     NaN    True     True
# ..         ...                          ...     ...     ...     ...      ...
# 954     huawei                Huawei Mate X  169000     NaN    True     True
# 957       vivo                    Vivo Y55S   13490     NaN   False    False
# 963       lava                      Lava X3    6999     NaN   False    False
# 972       itel                    itel A23s    4787     NaN   False    False
# 974       vivo                Vivo X Fold 2  119990     NaN    True     True
#
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom processor speed

# %%
df[df['processor_speed'].isnull()]
# Out:
#     brand_name                            model   price  rating  has_5g  \
# 27       apple          Apple iPhone 14 Pro Max  129990    76.0    True
# 78     samsung            Samsung Galaxy A34 5G   24999    75.0    True
# 100      apple              Apple iPhone 14 Pro  119990    75.0    True
# 118      tesla                   Tesla Pi Phone   69999    83.0    True
# 122     google                  Google Pixel 6A   29999    71.0    True
# 129     google                  Google Pixel 7A   34990    69.0    True
# 152      apple          Apple iPhone 15 Pro Max  142990    79.0    True
# 206    samsung            Samsung Galaxy A54 5G   34999    76.0    True
# 209      apple  Apple iPhone 14 Pro Max (256GB)  139990    77.0    True
# 224       vivo                         Vivo Y02    8999     NaN   False
# 241    samsung            Samsung Galaxy A75 5G   44999    83.0    True
# 255    samsung         Samsung Galaxy S22 FE 5G   51999    79.0    True
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom processor brand

# %%
df[df['processor_brand'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, num_front_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, extended_upto, resolution_width, resolution_height]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# Pengecekan nilai kosong pada kolom os

# %%
df[df['os'].isnull()]
# Out:
#     brand_name                       model   price  rating  has_5g  has_nfc  \
# 158       oppo             Oppo Find N2 5G   94990     NaN    True     True
# 304    samsung     Samsung Galaxy Z Flip 3   69999    84.0    True     True
# 320     royole            Royole FlexPai 2  109999    87.0    True    False
# 363       oppo            OPPO Find N Flip   89990    88.0    True     True
# 389       oppo           OPPO Find N2 Flip   70990    88.0    True     True
# 498    samsung  Samsung Galaxy Z Flip 4 5G   89999    88.0    True     True
# 561         lg                  LG Wing 5G   54999    89.0    True     True
# 599    oukitel                Oukitel WP21   22990    82.0   False    False
# 662         lg                LG V60 ThinQ   79990     NaN    True     True
# 699       asus  Asus ROG Phone 6D Ultimate  107990     NaN    True     True
# 704     huawei            Huawei Mate Xs 2  162990    89.0   False     True
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom battery capacity

# %%
df[df['battery_capacity'].isnull()]
# Out:
#     brand_name                         model   price  rating  has_5g  has_nfc  \
# 111      apple               Apple iPhone 12   51999    74.0    True     True
# 149      apple          Apple iPhone 12 Mini   40999    74.0    True     True
# 305      apple       Apple iPhone 12 (128GB)   55999    75.0    True     True
# 361      apple  Apple iPhone 12 Mini (128GB)   45999    75.0    True     True
# 435      apple        Apple iPhone SE 3 2022   43900     NaN    True     True
# 444      apple           Apple iPhone 15 Pro  130990    75.0    True     True
# 613      apple   Apple iPhone 12 Pro (512GB)  139900    80.0    True     True
# 737      apple             Apple iPhone SE 4   49990    60.0    True     True
# 824      apple   Apple iPhone 12 Pro (256GB)  119900    80.0    True     True
# 880      apple  Apple iPhone 12 Mini (256GB)   55999    75.0    True     True
# 881      apple       Apple iPhone 12 (256GB)   67999    76.0    True     True
#
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom num cores

# %%
df[df['num_cores'].isnull()]
# Out:
#     brand_name                    model   price  rating  has_5g  has_nfc  \
# 152      apple  Apple iPhone 15 Pro Max  142990    79.0    True     True
# 262      apple         Apple iPhone XR2   71999    60.0   False     True
# 280      apple     Apple iPhone 14 Mini   69990    70.0   False     True
# 425      nokia             Nokia X50 5G   34999    76.0    True    False
# 444      apple      Apple iPhone 15 Pro  130990    75.0    True     True
# 706      apple          Apple iPhone 15   82990    72.0   False     True
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 152           False          bionic        NaN              NaN  ...
# 262           False          bionic        NaN              NaN  ...
# 280           False          bionic        NaN              NaN  ...
# 425           False      snapdragon        NaN              NaN  ...
# 444           False          bionic        NaN              NaN  ...
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom primary camera front

# %%
df[df['primary_camera_front'].isnull()]
# Out:
#     brand_name                model   price  rating  has_5g  has_nfc  \
# 69        oppo     Oppo Find N Fold   99990     NaN    True     True
# 458     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN    True    False
# 599    oukitel         Oukitel WP21   22990    82.0   False    False
# 954     huawei        Huawei Mate X  169000     NaN    True     True
# 972       itel            itel A23s    4787     NaN   False    False
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 69            False      snapdragon        8.0             3.20  ...
# 458           False      snapdragon        8.0             2.96  ...
# 599           False           helio        8.0             2.20  ...
# 954            True           kirin        8.0             2.86  ...
# 972           False      spreadtrum        4.0             1.40  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 69            120                 2                NaN    other
# ...

# %% [markdown]
# Pengecekan nilai kosong pada kolom num front cameras

# %%
df[df['num_front_cameras'].isnull()]
# Out:
#     brand_name                model   price  rating  has_5g  has_nfc  \
# 69        oppo     Oppo Find N Fold   99990     NaN    True     True
# 458     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN    True    False
# 954     huawei        Huawei Mate X  169000     NaN    True     True
# 972       itel            itel A23s    4787     NaN   False    False
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 69            False      snapdragon        8.0             3.20  ...
# 458           False      snapdragon        8.0             2.96  ...
# 954            True           kirin        8.0             2.86  ...
# 972           False      spreadtrum        4.0             1.40  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 69            120                 2                NaN    other
# 458            60                 3                NaN  android
# 954            60                 4                NaN      NaN
# ...

# %% [markdown]
# # Melakukan Imputasi

# %% [markdown]
# Saya akan melakukan imputasi pada kolom extended_upto, fast_charging, rating, processor_speed, processor_brand, os, battery_capacity, num_cores, primary_camera_front, num_front_cameras dengan menggunakan mean, median, modus. Dikarenakan data yang hilang pada kolom ini berada dibawah 70% maka kita melakukan imputas.

# %% [markdown]
# Imputasi kolom extended upto

# %%
df['extended_upto'].dropna().describe()
# Out:
# count         980.0
# mean     736.032653
# std      261.939273
# min            32.0
# 25%           736.0
# 50%           736.0
# 75%          1024.0
# max          2048.0
# Name: extended_upto, dtype: Float64

# %%
mean_value = df['extended_upto'].dropna().mean()
df['extended_upto'] = df['extended_upto'].fillna(int(mean_value))

# %% [markdown]
# Imputasi kolom fast charging

# %%
df['fast_charging'].dropna().describe()
# Out:
# count    769.000000
# mean      46.126138
# std       34.277870
# min       10.000000
# 25%       18.000000
# 50%       33.000000
# 75%       66.000000
# max      240.000000
# Name: fast_charging, dtype: float64

# %%
df['fast_charging'] = df['fast_charging'].fillna(df['fast_charging'].dropna().mean())

# %% [markdown]
# Imputasi pada kolom rating

# %%
df['rating'].dropna().describe()
# Out:
# count    879.000000
# mean      78.258248
# std        7.402854
# min       60.000000
# 25%       74.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
df['rating'] = df['rating'].fillna(df['rating'].dropna().mean())

# %% [markdown]
# Imputasi pada kolom processor speed

# %%
df['processor_speed'].dropna().describe()
# Out:
# count    938.000000
# mean       2.427217
# std        0.464090
# min        1.200000
# 25%        2.050000
# 50%        2.300000
# 75%        2.840000
# max        3.220000
# Name: processor_speed, dtype: float64

# %%
df['processor_speed'] = df['processor_speed'].fillna(df['processor_speed'].dropna().mean())

# %% [markdown]
# Imputasi pada kolom processor brand

# %%
df['processor_brand'].dropna().describe()
# Out:
# count            960
# unique            13
# top       snapdragon
# freq             413
# Name: processor_brand, dtype: object

# %%
df['processor_brand'] = df['processor_brand'].fillna(df['processor_brand'].dropna().mode()[0])

# %% [markdown]
# Imputasi pada kolom os

# %%
df['os'].dropna().describe()
# Out:
# count         966
# unique          3
# top       android
# freq          909
# Name: os, dtype: object

# %%
df['os'] = df['os'].fillna(df['os'].dropna().mode()[0])

# %% [markdown]
# Imputasi pada kolom battery capacity

# %%
df['battery_capacity'].dropna().describe()
# Out:
# count      969.000000
# mean      4817.748194
# std       1009.540054
# min       1821.000000
# 25%       4500.000000
# 50%       5000.000000
# 75%       5000.000000
# max      22000.000000
# Name: battery_capacity, dtype: float64

# %%
df['battery_capacity'] = df['battery_capacity'].fillna(df['battery_capacity'].dropna().mode()[0])

# %% [markdown]
# Imputasi pada kolom num cores

# %%
df['num_cores'].dropna().describe()
# Out:
# count    974.000000
# mean       7.772074
# std        0.836845
# min        4.000000
# 25%        8.000000
# 50%        8.000000
# 75%        8.000000
# max        8.000000
# Name: num_cores, dtype: float64

# %%
df['num_cores'] = df['num_cores'].fillna(df['num_cores'].dropna().mode()[0])

# %% [markdown]
# Imputasi pada kolom primar camera front

# %%
df['primary_camera_front'].dropna().describe()
# Out:
# count    980.000000
# mean      16.586122
# std       10.849073
# min        0.300000
# 25%        8.000000
# 50%       16.000000
# 75%       16.000000
# max       60.000000
# Name: primary_camera_front, dtype: float64

# %%
df['primary_camera_front'] = df['primary_camera_front'].fillna(df['primary_camera_front'].dropna().mode()[0])

# %% [markdown]
# Imputasi pada kolom num front cameras

# %%
df['num_front_cameras'].dropna().describe()
# Out:
# count    976.000000
# mean       1.029713
# std        0.169882
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: num_front_cameras, dtype: float64

# %%
df['num_front_cameras'] = df['num_front_cameras'].fillna(df['num_front_cameras'].dropna().mode()[0])

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# # Duplikat

# %% [markdown]
# Karena disini tidak ada nilai terduplikat, maka saya tidak melakukan imputasi duplikat.

# %%
print("Menampilkan dupilcated values:")
df[df.duplicated()]
# Out:
# Menampilkan dupilcated values:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, num_front_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, extended_upto, resolution_width, resolution_height]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # Outliers

# %%
print("Pengecekan outliers:")

results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Pengecekan outliers:
# Kolom                      Persentase Outliers
# price                                10.918367
# rating                                2.755102
# num_cores                             7.653061
# processor_speed                       0.000000
# battery_capacity                     13.163265
# fast_charging_available              14.591837
# fast_charging                         1.428571
# ram_capacity                          1.122449
# internal_memory                      18.775510
# screen_size                          11.530612
# refresh_rate                          0.102041
# num_rear_cameras                      0.000000
# num_front_cameras                     2.959184
# primary_camera_rear                   1.836735
# primary_camera_front                 19.693878
# extended_memory_available             0.000000
# extended_upto                         0.000000
# resolution_width                     39.489796
# ...

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# Melakukan Imputasi

# %% [markdown]
# Dikarenakan disini pada kolom price, rating, num cores, fast charging, ram capacity, refresh rate, num front cameras, primary camera rear, resolution height ada data yang dibawah 10% maka saya akan melakukan imputasi nilai.

# %%
columns_to_impute = ["price", "rating", "num_cores", "fast_charging", "ram_capacity", "refresh_rate", "num_front_cameras", "primary_camera_rear", "resolution_height"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                      Persentase Outliers
# price                                 0.000000
# rating                                0.000000
# num_cores                             0.000000
# processor_speed                       0.000000
# battery_capacity                     13.163265
# fast_charging_available              14.591837
# fast_charging                         0.000000
# ram_capacity                          0.000000
# internal_memory                      18.775510
# screen_size                          11.530612
# refresh_rate                          0.000000
# num_rear_cameras                      0.000000
# num_front_cameras                     0.000000
# primary_camera_rear                   0.000000
# primary_camera_front                 19.693878
# extended_memory_available             0.000000
# extended_upto                         0.000000
# resolution_width                     39.489796
# resolution_height                     0.000000

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 976      honor                      Honor X8 5G  14990.0    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# # Inconsistent Values

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 976      honor                      Honor X8 5G  14990.0    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# Dikarenakan tidak ada inconsistent values pada data ini, maka saya tidak melakukan imputasi inconsistent values

# %% [markdown]
# # Construct Data

# %% [markdown]
# Disini saya mengkonstruksi data dengan menambahkan kolom flagship, yang artinya jika harga smrathphone >700 maka termasuk kriteria flagship (Yes), begitupun sebaliknya, jika harga smarthphone tersebut <700 maka bukan flagship (No)

# %%
df["flagship"] = df["price"].apply(lambda x: "Yes" if x > 700 else "No")

print(df.head())
# Out:
#   brand_name                      model    price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999.0    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499.0    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999.0    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999.0    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    num_rear_cameras  num_front_cameras       os  primary_camera_rear  \
# ...

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 976      honor                      Honor X8 5G  14990.0    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# # Data Reduction

# %% [markdown]
# Kemudian, saya mengurangi kolom fast charging available, dikarenakan infromasi ini sudah tercakup dalam fast charging.

# %%
df = df.drop('fast_charging_available', axis=1)

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 976      honor                      Honor X8 5G  14990.0    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...
